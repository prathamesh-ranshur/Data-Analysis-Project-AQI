# %% [markdown]
# <a href="https://colab.research.google.com/github/Data-Bender-dev/Data-Analysis-Project/blob/main/City_day__cleaning_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path = 'https://drive.google.com/drive/folders/1Kie3f5PRqZJplfxH7Qc9-ncY1Yx4HHzQ'
df = pd.read_csv(file_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-a1bdcdeafbf7> in <cell line: 0>()
#       1 import pandas as pd
#       2 file_path = 'https://drive.google.com/drive/folders/1Kie3f5PRqZJplfxH7Qc9-ncY1Yx4HHzQ'
# ----> 3 df = pd.read_csv(file_path)
#       4 df.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2949 fields in line 15, saw 6987

# %%
import pandas as pd
df = pd.read_csv("city_day.csv")

# %%
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
# prompt: replace the NAN value using interpolate

df.interpolate(method='linear', inplace=True)
# Out:
# <ipython-input-6-ab931b47ea49>:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear', inplace=True)

# %%
# prompt: check  for null values in entire dataset

import pandas as pd

# Assuming 'df' is already defined and loaded as in the previous code.
# If not, load it first:
# df = pd.read_csv("city_day.csv")

# Check for null values in the entire dataset
null_values = df.isnull().sum()

# Print the number of null values in each column
print(null_values)

# Optionally, you can also calculate the percentage of null values:
null_percentage = (df.isnull().sum() / len(df)) * 100
print("\nPercentage of null values:\n", null_percentage)
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64
#
# Percentage of null values:
#  City           0.000000
# Date           0.000000
# PM2.5         15.570079
# PM10          37.723071
# NO            12.129626
# NO2           12.139785
# NOx           14.171549
# NH3           34.973418
# CO             6.972334
# SO2           13.050692
# O3            13.619586
# Benzene       19.041008
# Toluene       27.229014
# Xylene        61.322001
# AQI           15.851139
# AQI_Bucket    15.851139
# dtype: float64

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05     0.00     0.00    0.00  50.0          Good
#
# [29531 rows x 16 columns]

# %%
df.interpolate(method='linear', inplace=True)
# Out:
# <ipython-input-8-a83f336b1194>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear', inplace=True)

# %% [markdown]
# # New Section

# %%
# prompt: replace NAN to null

df.fillna(value=pd.NA, inplace=True)
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN          <NA>
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN          <NA>
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN          <NA>
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN          <NA>
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN          <NA>
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05     0.00     0.00    0.00  50.0          Good
#
# [29531 rows x 16 columns]

# %%
# prompt: Using dataframe df: check negative values in columns excluding city and date

# Select all columns except 'City' and 'Date'
cols_to_check = df.columns.difference(['City', 'Date','AQI_Bucket'])

# Check for negative values in the selected columns
for col in cols_to_check:
    negative_values = df[df[col] < 0]
    if not negative_values.empty:
        print(f"Negative values found in column '{col}':")
        print(negative_values)
    else:
        print(f"No negative values found in column '{col}'")
# Out:
# No negative values found in column 'AQI'
# No negative values found in column 'Benzene'
# No negative values found in column 'CO'
# No negative values found in column 'NH3'
# No negative values found in column 'NO'
# No negative values found in column 'NO2'
# No negative values found in column 'NOx'
# No negative values found in column 'O3'
# No negative values found in column 'PM10'
# No negative values found in column 'PM2.5'
# No negative values found in column 'SO2'
# No negative values found in column 'Toluene'
# No negative values found in column 'Xylene'

# %%
# prompt: replace NaN with mean for PM 2.5 and PM 10

# Calculate the mean of 'PM2.5' and 'PM10', ignoring NaN values
mean_pm25 = df['PM2.5'].mean()
mean_pm10 = df['PM10'].mean()

# Replace NaN values in 'PM2.5' and 'PM10' with their respective means
df['PM2.5'].fillna(mean_pm25, inplace=True)
df['PM10'].fillna(mean_pm10, inplace=True)
# Out:
# <ipython-input-13-76d085c4005b>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM2.5'].fillna(mean_pm25, inplace=True)
# <ipython-input-13-76d085c4005b>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM10'].fillna(mean_pm10, inplace=True)

# %%
df
# Out:
#                 City        Date      PM2.5        PM10     NO    NO2    NOx  \
# 0          Ahmedabad  2015-01-01  68.024697  105.735055   0.92  18.22  17.15
# 1          Ahmedabad  2015-01-02  68.024697  105.735055   0.97  15.69  16.46
# 2          Ahmedabad  2015-01-03  68.024697  105.735055  17.40  19.30  29.70
# 3          Ahmedabad  2015-01-04  68.024697  105.735055   1.70  18.48  17.97
# 4          Ahmedabad  2015-01-05  68.024697  105.735055  22.10  21.42  37.76
# ...              ...         ...        ...         ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.020000   50.940000   7.68  25.06  19.54
# 29527  Visakhapatnam  2020-06-28  24.380000   74.090000   3.42  26.06  16.53
# 29528  Visakhapatnam  2020-06-29  22.910000   65.730000   3.45  29.53  18.33
# 29529  Visakhapatnam  2020-06-30  16.640000   49.970000   4.05  29.26  18.80
# 29530  Visakhapatnam  2020-07-01  15.000000   66.000000   0.40  26.85  14.05
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene   AQI  \
# 0        NaN   0.92  27.64  133.36     0.00     0.02    0.00   NaN
# 1        NaN   0.97  24.55   34.06     3.68     5.50    3.77   NaN
# 2        NaN  17.40  29.07   30.70     6.80    16.40    2.25   NaN
# 3        NaN   1.70  18.59   36.08     4.43    10.14    1.00   NaN
# 4        NaN  22.10  39.33   39.31     7.01    18.89    2.78   NaN
# ...      ...    ...    ...     ...      ...      ...     ...   ...
# 29526  12.47   0.47   8.55   23.30     2.24    12.07    0.73  41.0
# 29527  11.99   0.52  12.72   30.14     0.74     2.21    0.38  70.0
# 29528  10.71   0.48   8.42   30.96     0.01     0.01    0.00  68.0
# 29529  10.03   0.52   9.84   28.30     0.00     0.00    0.00  54.0
# 29530   5.20   0.59   2.10   17.05     0.00     0.00    0.00  50.0
#
#          AQI_Bucket
# 0              <NA>
# 1              <NA>
# 2              <NA>
# 3              <NA>
# 4              <NA>
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
# prompt: undo the previous changes

import pandas as pd

# Load the dataset (assuming it's in the same directory or provide the correct path)
df = pd.read_csv("city_day.csv")

# Display first few rows of the original DataFrame
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
# prompt: replace the NaN of AQI_Bucket with bfill inplace true

# Fill NaN values in 'AQI_Bucket' using backfill method
df['AQI_Bucket'].fillna(method='bfill', inplace=True)
# Out:
# <ipython-input-36-2cfae9fbe73f>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI_Bucket'].fillna(method='bfill', inplace=True)
# <ipython-input-36-2cfae9fbe73f>:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['AQI_Bucket'].fillna(method='bfill', inplace=True)

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0       0.92  27.64  133.36     0.00     0.02    0.00  162.847897
# 1       0.97  24.55   34.06     3.68     5.50    3.77  162.847897
# 2      17.40  29.07   30.70     6.80    16.40    2.25  162.847897
# 3       1.70  18.59   36.08     4.43    10.14    1.00  162.847897
# 4      22.10  39.33   39.31     7.01    18.89    2.78  162.847897
# ...      ...    ...     ...      ...      ...     ...         ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73   41.000000
# 29527   0.52  12.72   30.14     0.74     2.21    0.38   70.000000
# 29528   0.48   8.42   30.96     0.01     0.01    0.00   68.000000
# 29529   0.52   9.84   28.30     0.00     0.00    0.00   54.000000
# 29530   0.59   2.10   17.05      NaN      NaN     NaN   50.000000
#
#          AQI_Bucket
# 0              Poor
# 1              Poor
# 2              Poor
# 3              Poor
# 4              Poor
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
df['AQI'].interpolate(method='linear', inplace=True)
# Out:
# <ipython-input-23-52a75372e4eb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].interpolate(method='linear', inplace=True)

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN          Poor
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN          Poor
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN          Poor
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN          Poor
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN          Poor
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %%
# prompt: repleace NAN of AQI with interpolate

import pandas as pd

# Load the dataset
df = pd.read_csv("city_day.csv")

# Interpolate NaN values in the 'AQI' column using linear interpolation
df['AQI'].interpolate(method='linear', inplace=True)

# Display the updated DataFrame (optional)
df
# Out:
# <ipython-input-25-166fd6e5c598>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].interpolate(method='linear', inplace=True)
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %%
# prompt: I still see NaN in AQI

import pandas as pd

# Load the dataset
df = pd.read_csv("city_day.csv")

# Interpolate NaN values in the 'AQI' column using linear interpolation
df['AQI'].interpolate(method='linear', inplace=True)

# Fill any remaining NaN values in 'AQI' with the mean AQI
mean_aqi = df['AQI'].mean()
df['AQI'].fillna(mean_aqi, inplace=True)

# Display the updated DataFrame (optional)
df
# Out:
# <ipython-input-35-28207c472b70>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].interpolate(method='linear', inplace=True)
# <ipython-input-35-28207c472b70>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].fillna(mean_aqi, inplace=True)
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0       0.92  27.64  133.36     0.00     0.02    0.00  162.847897
# 1       0.97  24.55   34.06     3.68     5.50    3.77  162.847897
# 2      17.40  29.07   30.70     6.80    16.40    2.25  162.847897
# 3       1.70  18.59   36.08     4.43    10.14    1.00  162.847897
# 4      22.10  39.33   39.31     7.01    18.89    2.78  162.847897
# ...      ...    ...     ...      ...      ...     ...         ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73   41.000000
# 29527   0.52  12.72   30.14     0.74     2.21    0.38   70.000000
# 29528   0.48   8.42   30.96     0.01     0.01    0.00   68.000000
# 29529   0.52   9.84   28.30     0.00     0.00    0.00   54.000000
# 29530   0.59   2.10   17.05      NaN      NaN     NaN   50.000000
#
#          AQI_Bucket
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
df['Benzene'].interpolate(method='linear', inplace=True)
df['Toluene'].interpolate(method='linear', inplace=True)
df['Xylene'].interpolate(method='linear', inplace=True)
df
# Out:
# <ipython-input-34-096bcd8a8f84>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Benzene'].interpolate(method='linear', inplace=True)
# <ipython-input-34-096bcd8a8f84>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Toluene'].interpolate(method='linear', inplace=True)
# <ipython-input-34-096bcd8a8f84>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Xylene'].interpolate(method='linear', inplace=True)
#                 City        Date  PM2.5       PM10     NO    NO2    NOx  \
# 0          Ahmedabad  2015-01-01  47.74  77.793388   0.92  18.22  17.15
# 1          Ahmedabad  2015-01-02  47.74  77.793388   0.97  15.69  16.46
# 2          Ahmedabad  2015-01-03  47.74  77.793388  17.40  19.30  29.70
# 3          Ahmedabad  2015-01-04  47.74  77.793388   1.70  18.48  17.97
# 4          Ahmedabad  2015-01-05  47.74  77.793388  22.10  21.42  37.76
# ...              ...         ...    ...        ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.940000   7.68  25.06  19.54
# 29527  Visakhapatnam  2020-06-28  24.38  74.090000   3.42  26.06  16.53
# 29528  Visakhapatnam  2020-06-29  22.91  65.730000   3.45  29.53  18.33
# 29529  Visakhapatnam  2020-06-30  16.64  49.970000   4.05  29.26  18.80
# 29530  Visakhapatnam  2020-07-01  15.00  66.000000   0.40  26.85  14.05
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene   AQI  \
# 0        NaN   0.92  27.64  133.36     0.00     0.02    0.00   NaN
# 1        NaN   0.97  24.55   34.06     3.68     5.50    3.77   NaN
# 2        NaN  17.40  29.07   30.70     6.80    16.40    2.25   NaN
# 3        NaN   1.70  18.59   36.08     4.43    10.14    1.00   NaN
# 4        NaN  22.10  39.33   39.31     7.01    18.89    2.78   NaN
# ...      ...    ...    ...     ...      ...      ...     ...   ...
# 29526  12.47   0.47   8.55   23.30     2.24    12.07    0.73  41.0
# 29527  11.99   0.52  12.72   30.14     0.74     2.21    0.38  70.0
# 29528  10.71   0.48   8.42   30.96     0.01     0.01    0.00  68.0
# 29529  10.03   0.52   9.84   28.30     0.00     0.00    0.00  54.0
# 29530   5.20   0.59   2.10   17.05     0.00     0.00    0.00  50.0
#
#          AQI_Bucket
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene           0
# Toluene           0
# Xylene            0
# AQI               0
# AQI_Bucket     4681
# dtype: int64

# %%
# prompt: replace NaN in PM 2.5 and PM 10 with interpolate

import pandas as pd

# Load the dataset
df = pd.read_csv("city_day.csv")

# Interpolate NaN values in 'PM2.5' and 'PM10' using linear interpolation
df['PM2.5'].interpolate(method='linear', inplace=True)
df['PM10'].interpolate(method='linear', inplace=True)
df
# Out:
# <ipython-input-29-afbbe83f7443>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM2.5'].interpolate(method='linear', inplace=True)
# <ipython-input-29-afbbe83f7443>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM10'].interpolate(method='linear', inplace=True)
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %%
# prompt: repleace NaN of PM2.5 and PM10 with median

# Calculate the median of 'PM2.5' and 'PM10', ignoring NaN values
median_pm25 = df['PM2.5'].median()
median_pm10 = df['PM10'].median()

# Replace NaN values in 'PM2.5' and 'PM10' with their respective medians
df['PM2.5'].fillna(median_pm25, inplace=True)
df['PM10'].fillna(median_pm10, inplace=True)
df
# Out:
# <ipython-input-30-8ccc92a9dc8b>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM2.5'].fillna(median_pm25, inplace=True)
# <ipython-input-30-8ccc92a9dc8b>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM10'].fillna(median_pm10, inplace=True)
#                 City        Date  PM2.5       PM10     NO    NO2    NOx  \
# 0          Ahmedabad  2015-01-01  47.74  77.793388   0.92  18.22  17.15
# 1          Ahmedabad  2015-01-02  47.74  77.793388   0.97  15.69  16.46
# 2          Ahmedabad  2015-01-03  47.74  77.793388  17.40  19.30  29.70
# 3          Ahmedabad  2015-01-04  47.74  77.793388   1.70  18.48  17.97
# 4          Ahmedabad  2015-01-05  47.74  77.793388  22.10  21.42  37.76
# ...              ...         ...    ...        ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.940000   7.68  25.06  19.54
# 29527  Visakhapatnam  2020-06-28  24.38  74.090000   3.42  26.06  16.53
# 29528  Visakhapatnam  2020-06-29  22.91  65.730000   3.45  29.53  18.33
# 29529  Visakhapatnam  2020-06-30  16.64  49.970000   4.05  29.26  18.80
# 29530  Visakhapatnam  2020-07-01  15.00  66.000000   0.40  26.85  14.05
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene   AQI  \
# 0        NaN   0.92  27.64  133.36     0.00     0.02    0.00   NaN
# 1        NaN   0.97  24.55   34.06     3.68     5.50    3.77   NaN
# 2        NaN  17.40  29.07   30.70     6.80    16.40    2.25   NaN
# 3        NaN   1.70  18.59   36.08     4.43    10.14    1.00   NaN
# 4        NaN  22.10  39.33   39.31     7.01    18.89    2.78   NaN
# ...      ...    ...    ...     ...      ...      ...     ...   ...
# 29526  12.47   0.47   8.55   23.30     2.24    12.07    0.73  41.0
# 29527  11.99   0.52  12.72   30.14     0.74     2.21    0.38  70.0
# 29528  10.71   0.48   8.42   30.96     0.01     0.01    0.00  68.0
# 29529  10.03   0.52   9.84   28.30     0.00     0.00    0.00  54.0
# 29530   5.20   0.59   2.10   17.05      NaN      NaN     NaN  50.0
#
#          AQI_Bucket
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5             0
# PM10              0
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
# prompt: give percentage of null values for each col

null_percentage = (df.isnull().sum() / len(df)) * 100
print("\nPercentage of null values:\n", null_percentage)
# Out:
# Percentage of null values:
#  City           0.000000
# Date           0.000000
# PM2.5          0.000000
# PM10           0.000000
# NO            12.129626
# NO2           12.139785
# NOx           14.171549
# NH3           34.973418
# CO             6.972334
# SO2           13.050692
# O3            13.619586
# Benzene       19.041008
# Toluene       27.229014
# Xylene        61.322001
# AQI           15.851139
# AQI_Bucket    15.851139
# dtype: float64

# %%
# prompt: repleace the NAN of PM2.5 and PM10 with median, AQI and AQI_Bucket with interpolate and benzene,toluene,xylene with interpolate with inplace true

import pandas as pd

# Load the dataset
df = pd.read_csv("city_day.csv")

# Calculate the median of 'PM2.5' and 'PM10'
median_pm25 = df['PM2.5'].median()
median_pm10 = df['PM10'].median()

# Replace NaN values in 'PM2.5' and 'PM10' with their respective medians
df['PM2.5'].fillna(median_pm25, inplace=True)
df['PM10'].fillna(median_pm10, inplace=True)

# Interpolate 'AQI' and 'AQI_Bucket'
df['AQI'].interpolate(method='linear', inplace=True)
df['AQI_Bucket'].interpolate(method='linear', inplace=True)

# Interpolate 'Benzene', 'Toluene', and 'Xylene'
df['Benzene'].interpolate(method='linear', inplace=True)
df['Toluene'].interpolate(method='linear', inplace=True)
df['Xylene'].interpolate(method='linear', inplace=True)
df
# Out:
# <ipython-input-38-908490270934>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM2.5'].fillna(median_pm25, inplace=True)
# <ipython-input-38-908490270934>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM10'].fillna(median_pm10, inplace=True)
# <ipython-input-38-908490270934>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].interpolate(method='linear', inplace=True)
# <ipython-input-38-908490270934>:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI_Bucket'].interpolate(method='linear', inplace=True)
# <ipython-input-38-908490270934>:18: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df['AQI_Bucket'].interpolate(method='linear', inplace=True)
# <ipython-input-38-908490270934>:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Benzene'].interpolate(method='linear', inplace=True)
# <ipython-input-38-908490270934>:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Toluene'].interpolate(method='linear', inplace=True)
# <ipython-input-38-908490270934>:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Xylene'].interpolate(method='linear', inplace=True)
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01  48.57  95.68   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02  48.57  95.68   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03  48.57  95.68  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04  48.57  95.68   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05  48.57  95.68  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05     0.00     0.00    0.00  50.0          Good
#
# [29531 rows x 16 columns]
# Warning: total number of rows (29531) exceeds max_rows (20000). Limiting to first (20000) rows.
# Warning: total number of rows (29531) exceeds max_rows (20000). Limiting to first (20000) rows.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5             0
# PM10              0
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene           0
# Toluene           0
# Xylene            0
# AQI              28
# AQI_Bucket     4681
# dtype: int64

# %%
# prompt: give latest updated sheet

import pandas as pd

# Load the dataset
df = pd.read_csv("city_day.csv")

# Calculate the median of 'PM2.5' and 'PM10'
median_pm25 = df['PM2.5'].median()
median_pm10 = df['PM10'].median()

# Replace NaN values in 'PM2.5' and 'PM10' with their respective medians
df['PM2.5'].fillna(median_pm25, inplace=True)
df['PM10'].fillna(median_pm10, inplace=True)

# Interpolate 'AQI' using linear interpolation and fill remaining NaN with mean
df['AQI'].interpolate(method='linear', inplace=True)
mean_aqi = df['AQI'].mean()
df['AQI'].fillna(mean_aqi, inplace=True)

# Fill NaN values in 'AQI_Bucket' using backfill method
df['AQI_Bucket'].fillna(method='bfill', inplace=True)

# Interpolate 'Benzene', 'Toluene', and 'Xylene'
df['Benzene'].interpolate(method='linear', inplace=True)
df['Toluene'].interpolate(method='linear', inplace=True)
df['Xylene'].interpolate(method='linear', inplace=True)

# Check for and handle negative values (example for 'PM2.5', adapt for other columns)
df['PM2.5'] = df['PM2.5'].apply(lambda x: 0 if x < 0 else x)
df['PM10'] = df['PM10'].apply(lambda x: 0 if x < 0 else x)


# Display the updated DataFrame and null value counts
df.isnull().sum()
# Out:
# <ipython-input-40-6e3dff942336>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM2.5'].fillna(median_pm25, inplace=True)
# <ipython-input-40-6e3dff942336>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM10'].fillna(median_pm10, inplace=True)
# <ipython-input-40-6e3dff942336>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].interpolate(method='linear', inplace=True)
# <ipython-input-40-6e3dff942336>:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].fillna(mean_aqi, inplace=True)
# <ipython-input-40-6e3dff942336>:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI_Bucket'].fillna(method='bfill', inplace=True)
# <ipython-input-40-6e3dff942336>:22: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['AQI_Bucket'].fillna(method='bfill', inplace=True)
# <ipython-input-40-6e3dff942336>:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Benzene'].interpolate(method='linear', inplace=True)
# <ipython-input-40-6e3dff942336>:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Toluene'].interpolate(method='linear', inplace=True)
# <ipython-input-40-6e3dff942336>:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Xylene'].interpolate(method='linear', inplace=True)
# City              0
# Date              0
# PM2.5             0
# PM10              0
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene           0
# Toluene           0
# Xylene            0
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
# prompt: convert the latest sheet to csv

# Assuming 'df' is already processed as in the provided code.
df.to_csv('processed_city_day.csv', index=False)

# %%
df = pd.read_csv('processed_city_day.csv')
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01  48.57  95.68   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02  48.57  95.68   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03  48.57  95.68  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04  48.57  95.68   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05  48.57  95.68  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene         AQI  \
# 0       0.92  27.64  133.36     0.00     0.02    0.00  162.847897
# 1       0.97  24.55   34.06     3.68     5.50    3.77  162.847897
# 2      17.40  29.07   30.70     6.80    16.40    2.25  162.847897
# 3       1.70  18.59   36.08     4.43    10.14    1.00  162.847897
# 4      22.10  39.33   39.31     7.01    18.89    2.78  162.847897
# ...      ...    ...     ...      ...      ...     ...         ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73   41.000000
# 29527   0.52  12.72   30.14     0.74     2.21    0.38   70.000000
# 29528   0.48   8.42   30.96     0.01     0.01    0.00   68.000000
# 29529   0.52   9.84   28.30     0.00     0.00    0.00   54.000000
# 29530   0.59   2.10   17.05     0.00     0.00    0.00   50.000000
#
#          AQI_Bucket
# 0              Poor
# 1              Poor
# 2              Poor
# 3              Poor
# 4              Poor
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 16 columns]

# %%
# prompt: give the quality of the new sheet

import pandas as pd

# Load the dataset
df = pd.read_csv("processed_city_day.csv")

# Calculate the median of 'PM2.5' and 'PM10'
median_pm25 = df['PM2.5'].median()
median_pm10 = df['PM10'].median()

# Replace NaN values in 'PM2.5' and 'PM10' with their respective medians
df['PM2.5'].fillna(median_pm25, inplace=True)
df['PM10'].fillna(median_pm10, inplace=True)

# Interpolate 'AQI' using linear interpolation and fill remaining NaN with mean
df['AQI'].interpolate(method='linear', inplace=True)
mean_aqi = df['AQI'].mean()
df['AQI'].fillna(mean_aqi, inplace=True)

# Fill NaN values in 'AQI_Bucket' using backfill method
df['AQI_Bucket'].fillna(method='bfill', inplace=True)

# Interpolate 'Benzene', 'Toluene', and 'Xylene'
df['Benzene'].interpolate(method='linear', inplace=True)
df['Toluene'].interpolate(method='linear', inplace=True)
df['Xylene'].interpolate(method='linear', inplace=True)

# Check for and handle negative values (example for 'PM2.5', adapt for other columns)
df['PM2.5'] = df['PM2.5'].apply(lambda x: 0 if x < 0 else x)
df['PM10'] = df['PM10'].apply(lambda x: 0 if x < 0 else x)

# Check the quality of the processed data
null_counts = df.isnull().sum()
print("Null value counts after processing:\n", null_counts)

negative_counts = df[df < 0].count()  # Count negative values across all columns
print("\nNegative value counts after processing:\n", negative_counts)

# Display the updated DataFrame
df.head()
# Out:
# Null value counts after processing:
#  City              0
# Date              0
# PM2.5             0
# PM10              0
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene           0
# Toluene           0
# Xylene            0
# AQI               0
# AQI_Bucket        0
# dtype: int64
# <ipython-input-44-ee3b60ca05aa>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM2.5'].fillna(median_pm25, inplace=True)
# <ipython-input-44-ee3b60ca05aa>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PM10'].fillna(median_pm10, inplace=True)
# <ipython-input-44-ee3b60ca05aa>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].interpolate(method='linear', inplace=True)
# <ipython-input-44-ee3b60ca05aa>:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI'].fillna(mean_aqi, inplace=True)
# <ipython-input-44-ee3b60ca05aa>:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AQI_Bucket'].fillna(method='bfill', inplace=True)
# <ipython-input-44-ee3b60ca05aa>:22: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['AQI_Bucket'].fillna(method='bfill', inplace=True)
# <ipython-input-44-ee3b60ca05aa>:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Benzene'].interpolate(method='linear', inplace=True)
# <ipython-input-44-ee3b60ca05aa>:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Toluene'].interpolate(method='linear', inplace=True)
# <ipython-input-44-ee3b60ca05aa>:27: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Xylene'].interpolate(method='linear', inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ee3b60ca05aa> in <cell line: 0>()
#      35 print("Null value counts after processing:\n", null_counts)
#      36
# ---> 37 negative_counts = df[df < 0].count()  # Count negative values across all columns
#      38 print("\nNegative value counts after processing:\n", negative_counts)
#      39
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
# -> 7900         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7901         return self._construct_result(new_data)
#    7902
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    7943         if not is_list_like(right):
#    7944             # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7945             bm = self._mgr.apply(array_op, right=right)
#    7946             return self._constructor_from_mgr(bm, axes=bm.axes)
#    7947
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     359
#     360             if callable(f):
# --> 361                 applied = b.apply(f, **kwargs)
#     362             else:
#     363                 applied = getattr(b, f)(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     342
#     343     elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     345
#     346     else:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#     127         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128     else:
# --> 129         result = libops.scalar_compare(x.ravel(), y, op)
#     130     return result.reshape(x.shape)
#     131
#
# ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# prompt: what is the quality of the Processed_city_day.csv

# Load the dataset
df = pd.read_csv("processed_city_day.csv")

# Check the quality of the processed data
null_counts = df.isnull().sum()
print("Null value counts after processing:\n", null_counts)

negative_counts = (df < 0).sum()  # Count negative values across all columns
print("\nNegative value counts after processing:\n", negative_counts)

# Additional quality checks (optional):
# 1. Data type validation:
print("\nData types:\n", df.dtypes)

# 2. Statistical summary:
print("\nDescriptive statistics:\n", df.describe())

# 3. Check for duplicates:
print("\nNumber of duplicate rows:", df.duplicated().sum())

# 4. Check the unique values in categorical columns:
print("\nUnique values in 'City':", df['City'].unique())
print("\nUnique values in 'AQI_Bucket':", df['AQI_Bucket'].unique())
# Out:
# Null value counts after processing:
#  City              0
# Date              0
# PM2.5             0
# PM10              0
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene           0
# Toluene           0
# Xylene            0
# AQI               0
# AQI_Bucket        0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-1103e2f229ab> in <cell line: 0>()
#       8 print("Null value counts after processing:\n", null_counts)
#       9
# ---> 10 negative_counts = (df < 0).sum()  # Count negative values across all columns
#      11 print("\nNegative value counts after processing:\n", negative_counts)
#      12
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
# -> 7900         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7901         return self._construct_result(new_data)
#    7902
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    7943         if not is_list_like(right):
#    7944             # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7945             bm = self._mgr.apply(array_op, right=right)
#    7946             return self._constructor_from_mgr(bm, axes=bm.axes)
#    7947
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     359
#     360             if callable(f):
# --> 361                 applied = b.apply(f, **kwargs)
#     362             else:
#     363                 applied = getattr(b, f)(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     342
#     343     elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     345
#     346     else:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#     127         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128     else:
# --> 129         result = libops.scalar_compare(x.ravel(), y, op)
#     130     return result.reshape(x.shape)
#     131
#
# ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
df = pd.read_csv('processed_city_day.csv')
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['AQI'])
plt.show()
